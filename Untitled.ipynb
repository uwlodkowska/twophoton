# %%
cells_dict = {}

# %%
cells_dict[1] = 'aaa'

# %%
cells_dict
# Out:
# {1: 'aaa'}

# %%
tst = [None]*3

# %%
tst
# Out:
# [None, None, None]

# %%
tst.count(None)
# Out:
# 3

# %%
b = []

# %%
b.insert(0,5)

# %%
b
# Out:
# [5, 3]

# %%
a = {1:'abc'}

# %%
2 in a.keys()
# Out:
# False

# %%
a = [1,2,3,4,5,6]

# %%
a[:3]
# Out:
# [1, 2, 3]

# %%
a = []
a.append([1])
a.append([3,2,1])
a.append([2,1])
a
# Out:
# [[1], [3, 2, 1], [2, 1]]

# %%
	for i in range(3):
		for j in range(i-1, -1, -1):
            print(j,i)
# Out:
# 0 1
# 1 2
# 0 2

# %%
[i for i in range(5, -1, -1)]
# Out:
# [5, 4, 3, 2, 1, 0]

# %%
[[None]*3, [None]*3]
# Out:
# [[None, None, None], [None, None, None]]

# %%
a = ['a', 'b', 'c']

# %%
a.index('d')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-8955d7d8e4f0> in <module>()
# ----> 1 a.index('d')
#
# ValueError: 'd' is not in list
