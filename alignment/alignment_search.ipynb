# %%
from skimage import io
import numpy as np

# %%
dir_path = "/media/ula/DATADRIVE1/fos_gfp_tmaze/ctx_landmark/despeckle/trans_tst/"
namebase = "tst"
ext = ".tif"

minv = 5000;
minx = 0;
miny = 0;
minz = 0;

search_window = 12;
stack_window = 6;
substack_size = 5;

# %%
orig1 = io.imread(dir_path+namebase+"1"+ext)
orig2 = io.imread(dir_path+namebase+"2"+ext)

z1 = orig1.shape[0]
z2 = orig2.shape[0]

# %%
print(orig1.shape)
print(orig2.shape)
# Out:
# (70, 512, 512)
# (73, 512, 512)

# %%
for z in range(-stack_window, stack_window):
    tst1 = orig1[max(0,z) : min(z1, z2+z)];
    tst2 = orig2[max(0,-z) : min(z1-z, z2)];
    for x in range(-search_window, search_window):
        for y in range(-search_window, search_window):
            xdif = 512-abs(x);
            ydif = 512-abs(y);
            tst1_tmp = tst1[:,max(0,x):max(0,x)+xdif,max(0,y):max(0,y)+ydif]
            tst2_tmp = tst2[:,max(0,-x):max(0,-x)+xdif,max(0,-y):max(0,-y)+ydif]
            dif_tmp = abs(tst1_tmp - tst2_tmp)
            tmp_avg = np.average(dif_tmp)
            print(tmp_avg,x, y, dif_tmp.shape)
            if tmp_avg < minv:
                minv = tmp_avg
                minz = z
                minx = x
                miny = y
# Out:
# 0.05342167164179105 -12 -12 (67, 500, 500)
# 0.05317800220454613 -12 -11 (67, 500, 501)
# 0.05295682939882262 -12 -10 (67, 500, 502)
# 0.052758968576600104 -12 -9 (67, 500, 503)
# 0.052591506751954516 -12 -8 (67, 500, 504)
# 0.05246850894044628 -12 -7 (67, 500, 505)
# 0.05236068668515132 -12 -6 (67, 500, 506)
# 0.052268833348052636 -12 -5 (67, 500, 507)
# 0.05219402985074627 -12 -4 (67, 500, 508)
# 0.05212350819575991 -12 -3 (67, 500, 509)
# 0.05202598770851624 -12 -2 (67, 500, 510)
# 0.051904197213540906 -12 -1 (67, 500, 511)
# 0.05177472014925373 -12 0 (67, 500, 512)
# 0.05186459093962672 -12 1 (67, 500, 511)
# 0.05197623646473515 -12 2 (67, 500, 510)
# 0.05210931589596223 -12 3 (67, 500, 509)
# 0.0522529674462334 -12 4 (67, 500, 508)
# 0.05241119844564161 -12 5 (67, 500, 507)
# 0.05256663323697717 -12 6 (67, 500, 506)
# 0.05271103886508054 -12 7 (67, 500, 505)
# 0.05284446813551291 -12 8 (67, 500, 504)
# 0.052971840598201834 -12 9 (67, 500, 503)
# ...

# %%
print(minx, miny, minz)
# Out:
# 8 -3 3

# %%
io.imshow(dif_tmp[50])
# Out:
# /home/ula/anaconda3/lib/python3.8/site-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
