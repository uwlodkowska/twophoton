# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook
plt.ioff()

# %%
df.columns
# Out:
# Index([], dtype='object')

# %%
df = pd.DataFrame([])

# %%
a = np.array([[1,4],[2,1],[0,2]])

# %%
a
# Out:
# array([[1, 4],
#        [2, 1],
#        [0, 2]])

# %%
x=0

# %%
half=1.5

# %%
df = pd.DataFrame(a)

# %%
from scipy.spatial import distance
vectorList = [(0, 10), (4, 8), (14, 14), (16, 19), (35, 16)]
print(vectorList)
arr = np.asarray(vectorList).astype(float)
print(arr)
dis = distance.cdist(arr, arr).diagonal(1)
print(dis)
# Out:
# [(0, 10), (4, 8), (14, 14), (16, 19), (35, 16)]
# [[ 0. 10.]
#  [ 4.  8.]
#  [14. 14.]
#  [16. 19.]
#  [35. 16.]]
# [ 4.47213595 11.66190379  5.38516481 19.23538406]

# %%
df['isB'] = df[x]>=half
trial_size = 2

# %%
df['trial_no'] = df.index//trial_size

# %%
df.groupby(by=["trial_no"], dropna=False).sum()
# Out:
#    0  1    isB  trial_no
# 0  1  4  False         0
# 1  2  1   True         0
# 2  0  2  False         1

# %%
df = df.groupby(by=["trial_no"], dropna=False).sum()

# %%
df_list = [df]

# %%
for idx, df in enumerate(df_list):
    df.to_csv(file_dir.format(str(idx+1)+"grouped"))
# Out:
# <img src="data:image/png;base64,..." width="640">
